# %% [markdown]
# <a href="https://colab.research.google.com/github/KruthikaJ1109/Titanic_survival_prediction/blob/main/Task_1_Titanic_survival_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/Titanic-Dataset (1).csv')
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
val=df.drop('Survived',axis='columns')
to_predict=df.Survived
d=pd.get_dummies(val.Sex)
val=pd.concat([val,d],axis='columns')
val.drop('Sex',axis='columns',inplace=True)
val.head()
# Out:
#    Pclass   Age     Fare  female  male
# 0       3  22.0   7.2500       0     1
# 1       1  38.0  71.2833       1     0
# 2       3  26.0   7.9250       1     0
# 3       1  35.0  53.1000       1     0
# 4       3  35.0   8.0500       0     1

# %%
to_predict.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
val.columns[val.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
val.Age=val.Age.fillna(val.Age.mean())
val.columns[val.isna().any()]
# Out:
# Index([], dtype='object')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
a,b,c,d=train_test_split(val,to_predict,test_size=0.2)
m=GaussianNB()
m.fit(a,c)
# Out:
# GaussianNB()

# %%
m.score(b,d)
# Out:
# 0.7821229050279329

# %%
b[15:21]
# Out:
#      Pclass        Age     Fare  female  male
# 246       3  25.000000   7.7750       1     0
# 178       2  30.000000  13.0000       0     1
# 275       1  63.000000  77.9583       1     0
# 149       2  42.000000  13.0000       0     1
# 284       1  29.699118  26.0000       0     1
# 630       1  80.000000  30.0000       0     1

# %%
d[15:21]
# Out:
# 246    0
# 178    0
# 275    1
# 149    0
# 284    0
# 630    1
# Name: Survived, dtype: int64

# %%
m.predict(b[15:21])
# Out:
# array([1, 0, 1, 0, 0, 0])
